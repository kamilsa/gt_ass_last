# %%
# %matplotlib inline
import networkx as nx
from networkx.generators.classic import complete_graph
import itertools

# %%
g = nx.karate_club_graph()

# %%
nx.draw_networkx(g, pos = nx.spring_layout(g))

# %%
import operator
# max(nx.betweenness_centrality(g), key=operator.itemgetter(1))
# max(nx.betweenness_centrality(g))
# max(nx.degree_centrality(g))
betwennes = nx.betweenness_centrality(g)
degree = nx.degree_centrality(g)
max(betwennes, key=betwennes.get), max(degree, key=degree.get)
# Out:
# (0, 33)

# %%
type(stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5c5aa3daeb7e> in <module>()
# ----> 1 type(stats)
#
# NameError: name 'stats' is not defined

# %%
import operator
stats = {'a':1000, 'b':3000, 'c': 100}
max(nx.betweenness_centrality(g), key=operator.itemgetter(1))[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-fe9e1cf4befa> in <module>()
#       1 import operator
#       2 stats = {'a':1000, 'b':3000, 'c': 100}
# ----> 3 max(nx.betweenness_centrality(g), key=operator.itemgetter(1))[0]
#
# TypeError: 'int' object is not subscriptable

# %%
n = 5
g = complete_graph(n)
res = None
all_edges = []
m = len(nx.edges(g))
for i in range(m):
    all_edges += itertools.combinations(g.edges(), i)
print(len(all_edges))
for to_remove in all_edges:
    g = complete_graph(n)
    g.remove_edges_from(to_remove)
    betwennes = nx.betweenness_centrality(g)
    degree = nx.degree_centrality(g)
    bet, deg = max(betwennes, key=betwennes.get), max(degree, key=degree.get)
    if (deg != bet):
        print("Success")
        res = g
        break
# Out:
# 1023
# Success

# %%
nx.draw_networkx(res, pos = nx.circular_layout(res))

# %%
print(nx.betweenness_centrality(res))
print(nx.degree_centrality(res))
max(betwennes, key=betwennes.get), max(degree, key=degree.get)
# Out:
# {0: 0.05555555555555555, 1: 0.05555555555555555, 2: 0.05555555555555555, 3: 0.16666666666666666, 4: 0.16666666666666666}
# {0: 0.5, 1: 0.75, 2: 0.75, 3: 0.75, 4: 0.75}
# (3, 1)

# %%
from collections import defaultdict
b = defaultdict(list)
# Out:
# defaultdict(list, {43: ['29', '22'], 134: ['31', '2']})
